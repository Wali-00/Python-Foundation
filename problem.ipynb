# %% [markdown]
# 1.summation of last digit

# %%
N=int(input());
M=int(input());
print((N%10)+(M%10));
# Out:
# 5

# %% [markdown]
# 2.summation of last digit..take input in one line

# %%
inp= input();
number = inp.split();
x=int(number[0]);
y=int(number[1]);
print((x %10)+(y %10));
# Out:
# 5
