# %%
raining = True;
muddy = True;

if raining == True:
    print("It's raining, better take an umbrella!")
    if muddy == True:
        print("It's also muddy, wear boots!")
    else:
            print("It's not muddy, regular shoes are fine.")

else:
    print("It's not raining, no need for an umbrella.")
    if muddy == True:
        print("It's muddy, wear boots!")
    else:
        print("It's not muddy, regular shoes are fine.")
# Out:
# It's raining, better take an umbrella!
# It's also muddy, wear boots!

# %% [markdown]
# if money greater than 500 i will go outside
# if money greater than 400 i will order food
# if money greater than 300 i will buy a new game
# if less then this i will saving the money

# %%
money = int(input("How much money do you have? "))

if money >= 500:
    print("i will go outside")

if money < 500:
    if money >= 400:
        print("i will order food")    
if money < 400:
    if money >= 300:
        print("i will buy a new game")
if money < 300:
    print("i will saving the money")
# Out:
# i will saving the money

# %%
money = int(input("How much money do you have? "))

if money >= 500:
    print("i will go outside")


elif money >= 400:
    print("i will order food")    

elif money >= 300:
    print("i will buy a new game")
else:
    print("i will saving the money")
# Out:
# i will order food
