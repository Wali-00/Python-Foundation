# %%
sum=0;

for i in range(1,11):

    if  i % 2 == 0:
        print(i," is a even number, thats why it not added to the sum")
        continue;

    sum+=i;
    print(i," is added to the sum")
   
print(sum)
# Out:
# 1  is added to the sum
# 2  is a even number, thats why it not added to the sum
# 3  is added to the sum
# 4  is a even number, thats why it not added to the sum
# 5  is added to the sum
# 6  is a even number, thats why it not added to the sum
# 7  is added to the sum
# 8  is a even number, thats why it not added to the sum
# 9  is added to the sum
# 10  is a even number, thats why it not added to the sum
# 25

# %%
count = 45;

for i in range(100):
    if count>50:
        break
    print(count)
    count+=1;
# Out:
# 45
# 46
# 47
# 48
# 49
# 50
