# %%
phone_number = 45634

print(phone_number)
# Out:
# 45634

# %%
name = "wali"

print(name)
# Out:
# wali

# %%
age = 20
name = "wali"
is_passed= True
height= 5.6

print(type(age), type(name), type(is_passed), type(height))
# Out:
# <class 'int'> <class 'str'> <class 'bool'> <class 'float'>

# %% [markdown]
# Taking Input in Python

# %%
age= input()
print(age)
# Out:
# 20

# %%
age = input("enter your age:")
print(age, type(age))
# Out:
# 20 <class 'str'>

# %% [markdown]
# type casting

# %%
age = input("enter your age:")
age =int(age)
print(age, type(age))
# Out:
# 20 <class 'int'>

# %% [markdown]
# another way of type casting

# %%
height = float (input("enter your height"))

print(height, type(height))
# Out:
# 2.6 <class 'float'>

# %% [markdown]
# operator are +,-,*,/.%
#
# relational operator are
# >, <, <=, >=, ==, !=
# operator show only the boolean values
# True or False

# %%
x = 10
y = 3
print(round(x/y, 2)) #round show the value upto 2 decimal places
# Out:
# 3.33

# %% [markdown]
# Logical operator
# and
# or

# %%
x=10 
y=3
z=4

result = (x>y) and (x>z)
print(result)
# Out:
# True

# %%
x=10 
y=3
z=20

result = (x>y) or (x>z)
print(result)
# Out:
# True
